# %%
import cv2
import mediapipe as mp
from cvzone.PoseModule import PoseDetector

mp4_video = cv2.VideoCapture('people_walking_2.mp4')
video_detector = PoseDetector()
while True:
    success, mp4_image = mp4_video.read()
    #mp4_image = mp4_video.read()
    mp4_image = video_detector.findPose(mp4_image)
    lmList, bboxInfo = video_detector.findPosition(mp4_image, bboxWithHands = False)
    #bboxInfo = video_detector.findPosition(mp4_image, bboxWithHands = False)
    if bboxInfo:
        center = bboxInfo['center']
        cv2.circle(mp4_image, center, 5, (255, 0, 255), cv2.FILLED)
    cv2.imshow('mp4_image', mp4_image)
    if cv2.waitKey(0) & 0xFF == ord('q'):
        break
cap.release()
cv2.destroyAllWindows()
